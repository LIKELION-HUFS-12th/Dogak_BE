# %%
import pandas as pd

# %%
path1 = '/Users/oesikgogi/Desktop/도서관 정보나루/가락몰도서관 장서 대출목록 (2024년 09월).xlsx'

# %%
data1 = pd.read_excel(path1)
data1
# Out:
# /opt/anaconda3/envs/my_env/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#           번호                      도서명                              저자     출판사  \
# 0          1         편의점 비밀 요원:박주혜 동화                   박주혜 지음;정인하 그림      창비
# 1          2                말괄량이 길들이기             양태석,셰익스피어 원작,김혜연 그림  은하수미디어
# 2          3          루미너스 오늘부터 데뷔합니다                     김영주 글;하티 그림   다산어린이
# 3          4                    도시 해킹                          한수연 지음      책빛
# 4          5               내가 똑똑하다고?                     김윤아 글;강은옥 그림   천개의바람
# ...      ...                      ...                             ...     ...
# 37186  37187   제닝스는 꼴찌가 아니야 :영국 장편동화   앤터니 버커리지 지음 ;햇살과나무꾼 옮김 ;최정인 그림  사계절출판사
# 37187  37188                 상계동 아이들                   노경실 지음 ;김호민 그림     사계절
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37191 entries, 0 to 37190
# Data columns (total 13 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   번호       37191 non-null  int64
#  1   도서명      37191 non-null  object
#  2   저자       37189 non-null  object
#  3   출판사      36708 non-null  object
#  4   발행년도     37191 non-null  object
#  5   ISBN     37191 non-null  int64
#  6   세트 ISBN  2682 non-null   float64
#  7   부가기호     34771 non-null  object
#  8   권        8825 non-null   object
#  9   주제분류번호   37105 non-null  object
#  10  도서권수     37191 non-null  int64
#  11  대출건수     37191 non-null  int64
#  12  등록일자     37191 non-null  object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 3.7+ MB

# %%
# 필요없는 컬럼 삭제
    # 번호, 부가기호, 세트 ISBN, 권, 도서권수, 대출건수, 등록일자
data1.drop(columns=['번호', '세트 ISBN', '부가기호', '권', '도서권수', '대출건수', '등록일자'], inplace=True)

# %%
data1
# Out:
#                            도서명                              저자     출판사  발행년도  \
# 0             편의점 비밀 요원:박주혜 동화                   박주혜 지음;정인하 그림      창비  2020
# 1                    말괄량이 길들이기             양태석,셰익스피어 원작,김혜연 그림  은하수미디어  2024
# 2              루미너스 오늘부터 데뷔합니다                     김영주 글;하티 그림   다산어린이  2024
# 3                        도시 해킹                          한수연 지음      책빛  2024
# 4                   내가 똑똑하다고?                     김윤아 글;강은옥 그림   천개의바람  2024
# ...                        ...                             ...     ...   ...
# 37186   제닝스는 꼴찌가 아니야 :영국 장편동화   앤터니 버커리지 지음 ;햇살과나무꾼 옮김 ;최정인 그림  사계절출판사  2004
# 37187                 상계동 아이들                   노경실 지음 ;김호민 그림     사계절  2004
# 37188  (이원복 교수의)와인의 세계, 세계의 와인                        이원복 글.그림     김영사  2007
# 37189           눈 미끄럼 타는 할아버지                    이상권 글 ;심은숙 그림     시공사  2009
# 37190                동백꽃과 동박새                    이미숙 글 ;황연주 그림     마루벌  2001
#
#                 ISBN 주제분류번호
# ...

# %%
# 중복된 도서 확인
duplicate_books = data1[data1.duplicated(subset=['도서명', '저자'], keep=False)]
duplicate_books
# Out:
#                            도서명                             저자       출판사  발행년도  \
# 2              루미너스 오늘부터 데뷔합니다                    김영주 글;하티 그림     다산어린이  2024
# 8                       급식왕 GO  원작: 급식왕;글: 최재연;그림: 구은미;콘티: 서후  샌드박스네트워크  2024
# 14             루미너스 오늘부터 데뷔합니다                    김영주 글;하티 그림      다산북스  2024
# 19                      시간 고양이                   박미연 글;이소연 그림       이지북  2023
# 23               이상한 과자 가게 전천당       히로시마 레이코 지음;쟈쟈 그림;김정화 옮김      길벗스쿨  2024
# ...                        ...                            ...       ...   ...
# 37112  생명이 들려준 이야기 :위기철 창작동화집                  위기철 지음 ;이희재 그림    사계절출판사  2006
# 37160                  가족의 탄생                   허은미 글 ;한상언 그림     웅진씽크빅  2014
# 37175               마당을 나온 암탉                  황선미 지음 ;김환영 그림    사계절출판사  2000
# 37179     (책벌레 선생님의)아주 특별한 도서관                 임성미 지음 ;곽병철 그림     글담어린이  2008
# 37188  (이원복 교수의)와인의 세계, 세계의 와인                       이원복 글.그림       김영사  2007
#
#                 ISBN 주제분류번호
# ...

# %%
# 중복된 도서명과 저자 컬럼에서 첫 번째 행만 남기고 나머지 삭제
data1 = data1.drop_duplicates(subset=['도서명', '저자'], keep='first')
data1
# Out:
#                           도서명                              저자     출판사  발행년도  \
# 0            편의점 비밀 요원:박주혜 동화                   박주혜 지음;정인하 그림      창비  2020
# 1                   말괄량이 길들이기             양태석,셰익스피어 원작,김혜연 그림  은하수미디어  2024
# 2             루미너스 오늘부터 데뷔합니다                     김영주 글;하티 그림   다산어린이  2024
# 3                       도시 해킹                          한수연 지음      책빛  2024
# 4                  내가 똑똑하다고?                     김윤아 글;강은옥 그림   천개의바람  2024
# ...                       ...                             ...     ...   ...
# 37185                   라마야나      [발미키 원저] ;김재민 글 ;바드리 나라얀 그림     비룡소  2005
# 37186  제닝스는 꼴찌가 아니야 :영국 장편동화   앤터니 버커리지 지음 ;햇살과나무꾼 옮김 ;최정인 그림  사계절출판사  2004
# 37187                상계동 아이들                   노경실 지음 ;김호민 그림     사계절  2004
# 37189          눈 미끄럼 타는 할아버지                    이상권 글 ;심은숙 그림     시공사  2009
# 37190               동백꽃과 동박새                    이미숙 글 ;황연주 그림     마루벌  2001
#
#                 ISBN 주제분류번호
# ...

# %%
# 두번째 데이터 불러오기
path2 = '/Users/oesikgogi/Desktop/도서관 정보나루/가슴따뜻한작은도서관 장서 대출목록 (2024년 09월).xlsx'
data2 = pd.read_excel(path2)
data2
# Out:
# /opt/anaconda3/envs/my_env/lib/python3.12/site-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#       번호                                                도서명  \
# 0      1                                          북한산 역사 회복
# 1      2                         (매일매일 두뇌 트레이닝) 간단 종이접기 대백과
# 2      3  (Usborne)똥은 어디로 갈까요?:호기심 퐁퐁 플랩북 우리 아이의 첫 번째 질문과 답
# 3      4                                         질투 나서 속상해!
# 4      5                                    슬픔을 치료해 주는 비밀 책
# ..   ...                                                ...
# 630  631                                            용감한 아이린
# 631  632                                           날아라 슝슝 공
# 632  633                                              수학 귀신
# 633  634                                  돼지가 한 마리도 죽지 않던 날
# 634  635                             여행의 기술:알랭 드 보통의 여행 에세이
#
# ...

# %%
# 필요없는 컬럼 삭제
    # 번호, 부가기호, 세트 ISBN, 권, 도서권수, 대출건수, 등록일자
data2.drop(columns=['번호', '세트 ISBN', '부가기호', '권', '도서권수', '대출건수', '등록일자'], inplace=True)
data2.head()
# Out:
#                                                  도서명  \
# 0                                          북한산 역사 회복
# 1                         (매일매일 두뇌 트레이닝) 간단 종이접기 대백과
# 2  (Usborne)똥은 어디로 갈까요?:호기심 퐁퐁 플랩북 우리 아이의 첫 번째 질문과 답
# 3                                         질투 나서 속상해!
# 4                                    슬픔을 치료해 주는 비밀 책
#
#                               저자     출판사    발행년도           ISBN  주제분류번호
# 0                         호사카 유지  봄이아트북스  2022.0  9791166154386  911.60
# 1             주부의벗사 편집부 저;김수연 옮김   아르고나인  2011.0  9788997227099  634.90
# 2    케이티 데이니스 지음;댄 테일러 그림;신인수 옮김     NaN  2021.0  9791190183871  491.44
# 3  기슬렌 뒬리에 글;베랑제르 들라포르트 그림;정순 옮김    나무말미  2021.0  9791191827002  863.00
# 4  캐린 케이츠 글;웬디 앤더슨 핼퍼린 그림;이상희 옮김   봄봄출판사  2021.0  9791188909834  843.00

# %%
# 중복된 도서 확인
duplicate_books2 = data2[data2.duplicated(subset=['도서명', '저자'], keep=False)]
duplicate_books2
# Out:
#                                           도서명  \
# 1                  (매일매일 두뇌 트레이닝) 간단 종이접기 대백과
# 11   이토록 공부가 재미있어지는 순간:공부에 지친 청소년들을 위한 힐링 에세이
# 15                              평강공주:최사규 장편소설
# 16                              평강공주:최사규 장편소설
# 79                          기억:베르나르 베르베르 장편소설
# 80                          기억:베르나르 베르베르 장편소설
# 163                         죽음:베르나르 베르베르 장편소설
# 164                         죽음:베르나르 베르베르 장편소설
# 298                                       35년
# 299                                       35년
# 300                                       35년
# 334                                       오리진
# 335                                       오리진
# 342                        지적 대화를 위한 넓고 얕은 지식
# 355                                  삼백이의 칠일장
# 356                                  삼백이의 칠일장
# 388                              영웅이도 영웅이 필요해
# 412                        지적 대화를 위한 넓고 얕은 지식
# 421                              영웅이도 영웅이 필요해
# ...

# %%
# 중복된 도서명과 저자 컬럼에서 첫 번째 행만 남기고 나머지 삭제
data2 = data2.drop_duplicates(subset=['도서명', '저자'], keep='first')
data2
# Out:
#                                                    도서명  \
# 0                                            북한산 역사 회복
# 1                           (매일매일 두뇌 트레이닝) 간단 종이접기 대백과
# 2    (Usborne)똥은 어디로 갈까요?:호기심 퐁퐁 플랩북 우리 아이의 첫 번째 질문과 답
# 3                                           질투 나서 속상해!
# 4                                      슬픔을 치료해 주는 비밀 책
# ..                                                 ...
# 630                                            용감한 아이린
# 631                                           날아라 슝슝 공
# 632                                              수학 귀신
# 633                                  돼지가 한 마리도 죽지 않던 날
# 634                             여행의 기술:알랭 드 보통의 여행 에세이
#
#                                             저자     출판사    발행년도           ISBN  \
# 0                                       호사카 유지  봄이아트북스  2022.0  9791166154386
# 1                           주부의벗사 편집부 저;김수연 옮김   아르고나인  2011.0  9788997227099
# ...

# %%
df_combined = pd.concat([data1, data2], ignore_index=True)
df_combined
# Out:
#                           도서명                                         저자  \
# 0            편의점 비밀 요원:박주혜 동화                              박주혜 지음;정인하 그림
# 1                   말괄량이 길들이기                        양태석,셰익스피어 원작,김혜연 그림
# 2             루미너스 오늘부터 데뷔합니다                                김영주 글;하티 그림
# 3                       도시 해킹                                     한수연 지음
# 4                  내가 똑똑하다고?                                김윤아 글;강은옥 그림
# ...                       ...                                        ...
# 35047                 용감한 아이린                       윌리엄 스타이그 글·그림;김서정 옮김
# 35048                날아라 슝슝 공                               김용란 글;김유대 그림
# 35049                   수학 귀신  한스 마그누스 엔첸스베르거 지음;로트라우트 수잔네 베르너 그림;고영아 옮김
# 35050       돼지가 한 마리도 죽지 않던 날                         로버트 뉴턴 펙 지음;김옥수 옮김
# 35051  여행의 기술:알랭 드 보통의 여행 에세이                           알랭 드 보통 씀;정영목 옮김
#
#           출판사    발행년도           ISBN 주제분류번호
# 0          창비    2020  9788936451585  808.9
# ...

# %%
# 중복된 도서 확인
df_combined_check = df_combined[df_combined.duplicated(subset=['도서명', '저자'], keep=False)]
df_combined_check
# Out:
#                                            도서명                 저자      출판사  \
# 1562                                고양이 해결사 깜냥      홍민정 지음;김재희 그림       창비
# 2617                      꿀벌이 없어지면 딸기를 못 먹는다고?        김황 글;최현정 그림       창비
# 6292                                      뉴 키드  제리 크래프트 지음;조고은 옮김     푸른책들
# 6886                                열두 살 장래 희망      박성우 지음;홍그림 그림       창비
# 7757   메트로폴리스:인간의 가장 위대한 발명품, 도시의 역사로 보는 인류문명사     벤 윌슨 지음;박수철 옮김  매일경제신문사
# ...                                        ...                ...      ...
# 34855                                      지옥탕           손지희 글·그림     책읽는곰
# 34860                                   기억 전달자    로이스 로리 글;장은수 옮김      비룡소
# 34920                     꿀벌이 없어지면 딸기를 못 먹는다고?        김황 글;최현정 그림       창비
# 34983                                   대머리 사막           박경진 글·그림      미세기
# 35002                                       토지             박경리 지음     나남출판
#
#          발행년도           ISBN  주제분류번호
# ...

# %%
df_combined[df_combined.loc[:, '도서명'] == '고양이 해결사 깜냥']
# Out:
#               도서명             저자 출판사    발행년도           ISBN 주제분류번호
# 1562   고양이 해결사 깜냥  홍민정 지음;김재희 그림  창비    2023  9788936448523  813.8
# 2994   고양이 해결사 깜냥  홍민정 동화;김재희 그림  창비    2022  9788936448370  813.8
# 34514  고양이 해결사 깜냥  홍민정 지음;김재희 그림  창비  2020.0  9788936447694  813.8

# %%
# 데이터 전처리 순서

# 1. 데이터들 전부 합치기
# 2. 필요 없는 컬럼 제거
# 3. 중복 삭제
